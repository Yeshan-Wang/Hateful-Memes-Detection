# %%
# !nvidia-smi
# Out:
# Fri Jun 30 20:41:07 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0    41W / 400W |      0MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')

! unzip -q '/content/drive/MyDrive/hateful_memes.zip' -d '/content/data'
# Out:
# Mounted at /content/drive

# %%
! pip install --quiet ftfy regex tqdm
! pip install --quiet git+https://github.com/openai/CLIP.git
! pip install --quiet transformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 3.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for clip (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 84.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 29.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 105.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 82.9 MB/s eta 0:00:00

# %%
import os
import json
import pandas as pd
import numpy as np
import matplotlib.image as img

import torch
import torch.nn as nn
from torch.utils.data import DataLoader

import torchvision
from torchvision import transforms as T
import torchvision.transforms.functional as F

import cv2
import clip
from tqdm import tqdm
from PIL import Image
from sklearn.metrics import roc_auc_score
from transformers import AutoTokenizer, AutoModel

# %%
class ScaleMaxSideToSize(object):
  def __init__(self, size):
    self.size = size

  def __call__(self, sample):
    sample = cv2.resize(sample, (self.size, self.size), interpolation=cv2.INTER_AREA)

    return sample


class CropCenter(object):
  def __init__(self, size):
    self.size = size

  def __call__(self, sample):
    img = sample
    h, w, _ = img.shape
    margin_h = (h - self.size) // 2
    margin_w = (w - self.size) // 2
    sample = img[margin_h:margin_h + self.size, margin_w:margin_w + self.size]

    return sample

# %% [markdown]
# ## 1. Load dataset

# %%
class Load_Dataset(torch.utils.data.Dataset):
  def __init__(self, data_path, transforms):
    self.data = [json.loads(l) for l in open(data_path)]
    self.data_dir = os.path.dirname(data_path)
    self.transforms = transforms

  def __getitem__(self, index: int):
    path = os.path.join(self.data_dir, self.data[index]["img"])
    image = cv2.imread(path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    text = self.data[index]["text"]
    label = self.data[index]["label"]

    if self.transforms is not None:
        image = self.transforms(image)

    return image, text, label

  def __len__(self):
    return len(self.data)

# %%
CROP_SIZE = 336
MEAN = torch.tensor([0.485, 0.456, 0.406])
STD = torch.tensor([0.229, 0.224, 0.225])

transforms = T.Compose([
    ScaleMaxSideToSize(CROP_SIZE),
    CropCenter(CROP_SIZE),
    T.ToTensor(),
    T.Normalize(mean=MEAN, std=STD)])


train_path = '/content/data/hateful_memes/train.jsonl'
train_dataset = Load_Dataset(train_path, transforms)

dev_path = '/content/data/hateful_memes/dev_seen.jsonl'
dev_dataset = Load_Dataset(dev_path, transforms)

test_path = '/content/data/hateful_memes/test_seen.jsonl'
test_dataset = Load_Dataset(test_path, transforms)

# %% [markdown]
# ## 2. Use CLIP to encode each modality to get image and text features

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
CLIP_model, preprocess = clip.load('ViT-L/14@336px', device=device)

# Initialize RoBERTa tokenizer and model
tokenizer = AutoTokenizer.from_pretrained('cardiffnlp/twitter-roberta-base-offensive')
roberta_model = AutoModel.from_pretrained('cardiffnlp/twitter-roberta-base-offensive').to(device)
# Out:
# 100%|███████████████████████████████████████| 891M/891M [00:20<00:00, 45.1MiB/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/725 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-offensive were not used when initializing RobertaModel: ['classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.dense.weight', 'classifier.out_proj.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-offensive and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
def encode_features(clip_model, roberta_model, tokenizer, dataset):
  all_features = []
  all_labels = []

  with torch.no_grad():
    for images, texts, labels in tqdm(DataLoader(dataset, batch_size=100)):
      # Encode images with CLIP
      image_input = torch.tensor(np.stack(images)).to(device)
      image_features = clip_model.encode_image(image_input).type(torch.float).to(device)
      # Encode text with RoBERTa
      text_tokens = tokenizer.batch_encode_plus(texts, padding=True, return_tensors='pt').input_ids.to(device)
      text_features = roberta_model(text_tokens)[0][:, 0, :].type(torch.float).to(device)
      # Concatenate the features from different modalities into one shared vector space
      features = torch.cat([image_features, text_features], dim=1)
      all_features.extend(features)
      all_labels.extend(labels)

  return all_features, all_labels


# Get image & text features from train/dev/test set
features_train, labels_train = encode_features(CLIP_model, roberta_model, tokenizer, train_dataset)
features_dev, labels_dev = encode_features(CLIP_model, roberta_model, tokenizer, dev_dataset)
features_test, labels_test = encode_features(CLIP_model, roberta_model, tokenizer, test_dataset)
# Out:
# 100%|██████████| 85/85 [02:42<00:00,  1.91s/it]
# 100%|██████████| 5/5 [00:09<00:00,  1.88s/it]
# 100%|██████████| 10/10 [00:18<00:00,  1.86s/it]

# %%
class DefineDataset(torch.utils.data.Dataset):
  def __init__(self, features, labels):
    self.features = features
    self.labels = labels

  def __getitem__(self, index: int):
    return self.features[index], self.labels[index]

  def __len__(self):
    return len(self.features)


# Define train/dev/test set using image & text features and gold labels
train_set = DefineDataset(features_train, labels_train)
dev_set = DefineDataset(features_dev, labels_dev)
test_set = DefineDataset(features_test, labels_test)

# %% [markdown]
# ## 3. Construct a neural network for classification

# %%
torch.manual_seed(515)
input_shape = features_train[0].shape[0]
num_classes = 2
shape = 256

nn_model = nn.Sequential(
    nn.Linear(input_shape, shape),
    nn.Dropout(0.66),
    nn.BatchNorm1d(shape),
    nn.ReLU(inplace=True),

    nn.Linear(shape, shape),
    nn.Dropout(0.66),
    nn.BatchNorm1d(shape),
    nn.ReLU(inplace=True),

    nn.Linear(shape, num_classes),)

nn_model = nn_model.to(device)
loss = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(nn_model.parameters(), lr=1e-2)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.8)

# %% [markdown]
# ## 4. Train and validate the classification model and save the best model after 100 epochs of training

# %%
def get_lr(optimizer):
  for param_group in optimizer.param_groups:
    return param_group['lr']  # Retrieve the learning rate value from optimizer

def compute_auroc(model, loader):
  """
  Compute AUROC on the dataset wrapped in a loader
  Return: AUROC score as a float value between 0 and 1
  """
  model.eval()
  real_labels = []
  probabilities = []

  for i_step, (x, y) in enumerate(loader):
    x = x.to(device)
    y = y.to(device)
    prediction = model(x)
    # select probabilities corresponding to the positive class
    prediction = prediction[:, 1]  # positive class in the second column
    probabilities.extend(prediction.detach().cpu().numpy())
    real_labels.extend(y.detach().cpu().numpy())

  auroc = roc_auc_score(real_labels, probabilities)*100
  return auroc

# %%
train_loader = DataLoader(train_set, batch_size=500)
val_loader = DataLoader(dev_set, batch_size=500)
top_val_AUROC = 70

for epoch in range(100):
  nn_model.train()
  loss_accum = 0
  for i_step, (x, y) in enumerate(train_loader):
    x = x.to(device)
    y = y.to(device)
    prediction = nn_model(x)
    loss_value = loss(prediction, y.type(torch.long))
    optimizer.zero_grad()
    loss_value.backward()
    optimizer.step()
    loss_accum += loss_value

  ave_loss = loss_accum / (i_step + 1)
  val_AUROC = compute_auroc(nn_model, val_loader)
  print("Epoch: %i lr: %f; Average loss: %f, Val AUROC: %f" % (epoch, get_lr(optimizer), ave_loss, val_AUROC))

  if scheduler != None:
    scheduler.step()

  if val_AUROC > top_val_AUROC:
    top_val_AUROC = val_AUROC
    best_model_name = f'Best_model_{round(val_AUROC, 2)}.ckpt'
    torch.save(nn_model, open(best_model_name, 'wb'))
    print("saved", best_model_name)
# Out:
# Epoch: 0 lr: 0.010000; Average loss: 0.625265, Val AUROC: 72.520843
# saved Best_model_72.52.ckpt
# Epoch: 1 lr: 0.010000; Average loss: 0.510983, Val AUROC: 74.284297
# saved Best_model_74.28.ckpt
# Epoch: 2 lr: 0.010000; Average loss: 0.461446, Val AUROC: 74.884383
# saved Best_model_74.88.ckpt
# Epoch: 3 lr: 0.010000; Average loss: 0.436580, Val AUROC: 75.900530
# saved Best_model_75.9.ckpt
# Epoch: 4 lr: 0.010000; Average loss: 0.422415, Val AUROC: 75.882927
# Epoch: 5 lr: 0.010000; Average loss: 0.414615, Val AUROC: 75.777312
# Epoch: 6 lr: 0.010000; Average loss: 0.403871, Val AUROC: 76.314989
# saved Best_model_76.31.ckpt
# Epoch: 7 lr: 0.010000; Average loss: 0.385530, Val AUROC: 77.259125
# saved Best_model_77.26.ckpt
# Epoch: 8 lr: 0.010000; Average loss: 0.380072, Val AUROC: 77.459154
# saved Best_model_77.46.ckpt
# Epoch: 9 lr: 0.010000; Average loss: 0.366062, Val AUROC: 76.620633
# Epoch: 10 lr: 0.008000; Average loss: 0.357090, Val AUROC: 76.627034
# Epoch: 11 lr: 0.008000; Average loss: 0.339690, Val AUROC: 76.686243
# Epoch: 12 lr: 0.008000; Average loss: 0.327741, Val AUROC: 76.811061
# Epoch: 13 lr: 0.008000; Average loss: 0.319796, Val AUROC: 76.975885
# Epoch: 14 lr: 0.008000; Average loss: 0.306053, Val AUROC: 77.862412
# saved Best_model_77.86.ckpt
# Epoch: 15 lr: 0.008000; Average loss: 0.306768, Val AUROC: 76.955082
# Epoch: 16 lr: 0.008000; Average loss: 0.289696, Val AUROC: 77.976029
# saved Best_model_77.98.ckpt
# Epoch: 17 lr: 0.008000; Average loss: 0.281729, Val AUROC: 77.126306
# Epoch: 18 lr: 0.008000; Average loss: 0.282898, Val AUROC: 77.060697
# Epoch: 19 lr: 0.008000; Average loss: 0.279675, Val AUROC: 76.940679
# Epoch: 20 lr: 0.006400; Average loss: 0.257318, Val AUROC: 76.827063
# Epoch: 21 lr: 0.006400; Average loss: 0.242187, Val AUROC: 77.406347
# Epoch: 22 lr: 0.006400; Average loss: 0.232072, Val AUROC: 76.999888
# Epoch: 23 lr: 0.006400; Average loss: 0.228114, Val AUROC: 76.982285
# Epoch: 24 lr: 0.006400; Average loss: 0.220126, Val AUROC: 76.865469
# Epoch: 25 lr: 0.006400; Average loss: 0.223982, Val AUROC: 76.766254
# Epoch: 26 lr: 0.006400; Average loss: 0.209071, Val AUROC: 77.228721
# Epoch: 27 lr: 0.006400; Average loss: 0.202468, Val AUROC: 76.705446
# Epoch: 28 lr: 0.006400; Average loss: 0.204286, Val AUROC: 76.603031
# Epoch: 29 lr: 0.006400; Average loss: 0.195755, Val AUROC: 76.923077
# Epoch: 30 lr: 0.005120; Average loss: 0.181155, Val AUROC: 77.159911
# Epoch: 31 lr: 0.005120; Average loss: 0.174164, Val AUROC: 77.587173
# Epoch: 32 lr: 0.005120; Average loss: 0.170292, Val AUROC: 77.201517
# Epoch: 33 lr: 0.005120; Average loss: 0.159129, Val AUROC: 76.835064
# Epoch: 34 lr: 0.005120; Average loss: 0.151801, Val AUROC: 76.563025
# Epoch: 35 lr: 0.005120; Average loss: 0.147363, Val AUROC: 77.206318
# Epoch: 36 lr: 0.005120; Average loss: 0.145229, Val AUROC: 76.815861
# Epoch: 37 lr: 0.005120; Average loss: 0.143724, Val AUROC: 77.369541
# Epoch: 38 lr: 0.005120; Average loss: 0.132601, Val AUROC: 77.223920
# Epoch: 39 lr: 0.005120; Average loss: 0.140606, Val AUROC: 77.590373
# Epoch: 40 lr: 0.004096; Average loss: 0.126459, Val AUROC: 77.422349
# Epoch: 41 lr: 0.004096; Average loss: 0.115880, Val AUROC: 77.732794
# Epoch: 42 lr: 0.004096; Average loss: 0.109908, Val AUROC: 78.022435
# saved Best_model_78.02.ckpt
# Epoch: 43 lr: 0.004096; Average loss: 0.112211, Val AUROC: 76.849466
# Epoch: 44 lr: 0.004096; Average loss: 0.112640, Val AUROC: 77.689587
# Epoch: 45 lr: 0.004096; Average loss: 0.108123, Val AUROC: 77.812805
# Epoch: 46 lr: 0.004096; Average loss: 0.105048, Val AUROC: 77.665584
# Epoch: 47 lr: 0.004096; Average loss: 0.094532, Val AUROC: 77.183914
# Epoch: 48 lr: 0.004096; Average loss: 0.095618, Val AUROC: 77.457554
# Epoch: 49 lr: 0.004096; Average loss: 0.094224, Val AUROC: 77.329535
# Epoch: 50 lr: 0.003277; Average loss: 0.097591, Val AUROC: 77.812805
# Epoch: 51 lr: 0.003277; Average loss: 0.087878, Val AUROC: 76.919876
# Epoch: 52 lr: 0.003277; Average loss: 0.080883, Val AUROC: 77.508761
# Epoch: 53 lr: 0.003277; Average loss: 0.086539, Val AUROC: 77.790402
# Epoch: 54 lr: 0.003277; Average loss: 0.078914, Val AUROC: 77.212719
# Epoch: 55 lr: 0.003277; Average loss: 0.076621, Val AUROC: 77.780800
# Epoch: 56 lr: 0.003277; Average loss: 0.076914, Val AUROC: 77.872014
# Epoch: 57 lr: 0.003277; Average loss: 0.069097, Val AUROC: 77.992031
# Epoch: 58 lr: 0.003277; Average loss: 0.067661, Val AUROC: 77.292730
# Epoch: 59 lr: 0.003277; Average loss: 0.068594, Val AUROC: 76.854267
# Epoch: 60 lr: 0.002621; Average loss: 0.073233, Val AUROC: 77.347138
# Epoch: 61 lr: 0.002621; Average loss: 0.060436, Val AUROC: 77.198317
# Epoch: 62 lr: 0.002621; Average loss: 0.061769, Val AUROC: 77.129507
# Epoch: 63 lr: 0.002621; Average loss: 0.064853, Val AUROC: 77.585572
# Epoch: 64 lr: 0.002621; Average loss: 0.063047, Val AUROC: 77.286329
# Epoch: 65 lr: 0.002621; Average loss: 0.058796, Val AUROC: 77.107103
# Epoch: 66 lr: 0.002621; Average loss: 0.059556, Val AUROC: 77.335936
# Epoch: 67 lr: 0.002621; Average loss: 0.060505, Val AUROC: 77.143909
# Epoch: 68 lr: 0.002621; Average loss: 0.050379, Val AUROC: 76.964683
# Epoch: 69 lr: 0.002621; Average loss: 0.052481, Val AUROC: 76.884671
# Epoch: 70 lr: 0.002097; Average loss: 0.051716, Val AUROC: 77.126306
# Epoch: 71 lr: 0.002097; Average loss: 0.049359, Val AUROC: 77.161511
# Epoch: 72 lr: 0.002097; Average loss: 0.046633, Val AUROC: 76.993487
# Epoch: 73 lr: 0.002097; Average loss: 0.044938, Val AUROC: 76.791858
# Epoch: 74 lr: 0.002097; Average loss: 0.046841, Val AUROC: 77.214319
# Epoch: 75 lr: 0.002097; Average loss: 0.046860, Val AUROC: 77.153510
# Epoch: 76 lr: 0.002097; Average loss: 0.043283, Val AUROC: 77.233522
# Epoch: 77 lr: 0.002097; Average loss: 0.039213, Val AUROC: 77.177514
# Epoch: 78 lr: 0.002097; Average loss: 0.044839, Val AUROC: 77.659183
# Epoch: 79 lr: 0.002097; Average loss: 0.045404, Val AUROC: 77.227121
# Epoch: 80 lr: 0.001678; Average loss: 0.042516, Val AUROC: 76.945480
# Epoch: 81 lr: 0.001678; Average loss: 0.037946, Val AUROC: 77.123106
# Epoch: 82 lr: 0.001678; Average loss: 0.037216, Val AUROC: 77.065497
# Epoch: 83 lr: 0.001678; Average loss: 0.033255, Val AUROC: 77.206318
# Epoch: 84 lr: 0.001678; Average loss: 0.036930, Val AUROC: 77.051095
# Epoch: 85 lr: 0.001678; Average loss: 0.038012, Val AUROC: 77.252724
# Epoch: 86 lr: 0.001678; Average loss: 0.040128, Val AUROC: 77.111904
# Epoch: 87 lr: 0.001678; Average loss: 0.034339, Val AUROC: 77.574371
# Epoch: 88 lr: 0.001678; Average loss: 0.033262, Val AUROC: 77.385544
# Epoch: 89 lr: 0.001678; Average loss: 0.034716, Val AUROC: 77.230321
# Epoch: 90 lr: 0.001342; Average loss: 0.032247, Val AUROC: 77.750396
# Epoch: 91 lr: 0.001342; Average loss: 0.031624, Val AUROC: 77.731193
# Epoch: 92 lr: 0.001342; Average loss: 0.029478, Val AUROC: 77.305532
# Epoch: 93 lr: 0.001342; Average loss: 0.027741, Val AUROC: 77.212719
# Epoch: 94 lr: 0.001342; Average loss: 0.031915, Val AUROC: 77.366341
# Epoch: 95 lr: 0.001342; Average loss: 0.033161, Val AUROC: 77.241523
# Epoch: 96 lr: 0.001342; Average loss: 0.028829, Val AUROC: 77.326335
# Epoch: 97 lr: 0.001342; Average loss: 0.031134, Val AUROC: 77.287929
# Epoch: 98 lr: 0.001342; Average loss: 0.030366, Val AUROC: 77.353539
# Epoch: 99 lr: 0.001342; Average loss: 0.026855, Val AUROC: 77.676785

# %% [markdown]
# ## 5. test the best model

# %%
best_model = torch.load(open(best_model_name, 'rb'))
print(best_model)
# Out:
# Sequential(
#   (0): Linear(in_features=1536, out_features=256, bias=True)
#   (1): Dropout(p=0.66, inplace=False)
#   (2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (3): ReLU(inplace=True)
#   (4): Linear(in_features=256, out_features=256, bias=True)
#   (5): Dropout(p=0.66, inplace=False)
#   (6): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (7): ReLU(inplace=True)
#   (8): Linear(in_features=256, out_features=2, bias=True)
# )

# %%
best_model = best_model.to(device)
best_model.eval()

test_loader = DataLoader(test_set, batch_size=500)
real_labels = []
predictions = []

for i_step, (x, y) in enumerate(test_loader):
  x = x.to(device)
  y = y.to(device)
  prediction = best_model(x)
  # select probabilities corresponding to the positive class
  prediction = prediction[:, 1]  # positive class in the second column
  predictions.extend(prediction.detach().cpu().numpy())
  real_labels.extend(y.detach().cpu().numpy())

auroc_score = roc_auc_score(real_labels, predictions)*100
print('AUROC:', round(auroc_score, 2))
# Out:
# AUROC: 82.11
